# %% [markdown]
# <a href="https://colab.research.google.com/github/saamir16/MachineLearning/blob/main/IntroductiontoML/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PANDAS
# Data processing in ML using Pandas
# Data processing in required tasks for cleaning the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model
# Pandas is an open source Python pacage that is ost widely sed for daya science/data analysis and ML tasks. It is build on top of another pacage named Numpy, whhich provides support for multi-dimensional arrays. Processing is the process of doing a pre-analysis of data, in order to transfro them into a standart and normalized format.
#
# Proprocessing involves thhe following aspects:
# * missing values
# *  data standardization
#
# outlier: different attribute than other in data structure, like in group of students who have age ranging from 20 to 22, 32 age student is outlier

# %%
import pandas as pd

data ={
    "cars":["bmw", "honda", "suzuki", "byd"],
    "models": ["2007", "2008", "2015", "2025"],
    "passen": ["4", "6", "6", "5"]
}
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'byd'],
#  'models': ['2007', '2008', '2015', '2025'],
#  'passen': ['4', '6', '6', '5']}

# %%
df=pd.DataFrame(data)
df
# Out:
#      cars models passen
# 0     bmw   2007      4
# 1   honda   2008      6
# 2  suzuki   2015      6
# 3     byd   2025      5

# %%
df.to_csv("/content/drive/MyDrive/AsainCollege/car_data.csv ")
df
# Out:
#      cars models passen
# 0     bmw   2007      4
# 1   honda   2008      6
# 2  suzuki   2015      6
# 3     byd   2025      5

# %% [markdown]
# calories  duration
# 420       50
# 500       60
# 390       45

# %%
dict ={
    "calories":[420,500,390],
    "duration":[50,60,45]
}
dict
# Out:
# {'calories': [420, 500, 390], 'duration': [50, 60, 45]}

# %%
dataframe=pd.DataFrame(dict)
dataframe
# Out:
#    calories  duration
# 0       420        50
# 1       500        60
# 2       390        45

# %%
dataframe.to_csv("/content/drive/MyDrive/AsainCollege/calories.csv ")
dataframe
# Out:
#    calories  duration
# 0       420        50
# 1       500        60
# 2       390        45
